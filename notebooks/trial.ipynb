# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/station_county_mapping_final.csv')

df.head()
# Out:
#     station_id      lat       lon  fips_code     county_name source
# 0  US1TXAC0002  33.8281  -98.5492    48009.0   Archer County    fcc
# 1  US1TXAC0003  33.5838  -98.6298    48009.0   Archer County    fcc
# 2  US1TXAC0005  33.7762  -98.5350    48009.0   Archer County    fcc
# 3  US1TXAC0009  33.8328  -98.5360    48009.0   Archer County    fcc
# 4  US1TXAD0002  32.0533 -102.8796    48495.0  Winkler County    fcc

# %%
df.shape
# Out:
# (4798, 6)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4798 entries, 0 to 4797
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   station_id   4798 non-null   object
#  1   lat          4798 non-null   float64
#  2   lon          4798 non-null   float64
#  3   fips_code    4797 non-null   float64
#  4   county_name  4797 non-null   object
#  5   source       4798 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 225.0+ KB
# None
